# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from scipy import stats
import math
from datetime import datetime

ds=pd.read_csv('/content/drive/MyDrive/disney_plus.csv')

# %%
ds.dropna()

# %%
forks = ds.sort_values(by='release_year')
forks.head()
# Out:
#      show_id   type               title                director         cast  \
# 1220   s1221  Movie    Steamboat Willie  Walt Disney, Ub Iwerks  Walt Disney
# 893     s894  Movie   Flowers and Trees            Burt Gillett          NaN
# 1178   s1179  Movie    Santa's Workshop         Wilfred Jackson          NaN
# 736     s737  Movie  Babes in the Woods            Burt Gillett          NaN
# 1317   s1318  Movie      The Pied Piper         Wilfred Jackson          NaN
#
#             country         date_added  release_year rating duration  \
# 1220  United States  November 12, 2019          1928  TV-Y7    8 min
# 893   United States  November 12, 2019          1932  TV-Y7    8 min
# 1178  United States  November 12, 2019          1932   TV-G    7 min
# 736   United States  November 12, 2019          1932  TV-Y7    8 min
# 1317  United States  November 12, 2019          1933   TV-G    8 min
#
#                        listed_in  \
# 1220     Animation, Family, Kids
# ...

# %%
ds.isnull().any()
# Out:
# show_id         False
# type            False
# title           False
# director         True
# cast             True
# country          True
# date_added       True
# release_year    False
# rating           True
# duration        False
# listed_in       False
# description     False
# dtype: bool

# %%
ds[ds['rating'].isna()==1]
# Out:
#     show_id     type                           title            director  \
# 4        s5  TV Show           The Beatles: Get Back                 NaN
# 276    s277    Movie  Disney My Music Story: Perfume  Kentaro Takayanagi
# 280    s281  TV Show        Marvel Studios ASSEMBLED                 NaN
#
#                                                   cast country  \
# 4    John Lennon, Paul McCartney, George Harrison, ...     NaN
# 276                        a-chan , KASHIYUKA , NOCCHi     NaN
# 280                                                NaN     NaN
#
#             date_added  release_year rating  duration  \
# 4    November 25, 2021          2021    NaN  1 Season
# 276     March 19, 2021          2019    NaN    53 min
# 280     March 12, 2021          2021    NaN  1 Season
#
#                             listed_in  \
# 4       Docuseries, Historical, Music
# 276  Biographical, Documentary, Music
# 280             Anthology, Docuseries
#
# ...

# %%
ds.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1445    False
# 1446    False
# 1447    False
# 1448    False
# 1449    False
# Length: 1450, dtype: bool

# %%
ds[ds['title'].isin(['Duck the Halls: A Mickey Mouse Christmas Special','Enchanted'])]
# Out:
#    show_id   type                                             title  \
# 0       s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 19     s20  Movie                                         Enchanted
#
#                              director  \
# 0   Alonso Ramirez Ramos, Dave Wasson
# 19                         Kevin Lima
#
#                                                  cast        country  \
# 0   Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 19  Amy Adams, Patrick Dempsey, James Marsden, Tim...  United States
#
#            date_added  release_year rating duration                listed_in  \
# 0   November 26, 2021          2016   TV-G   23 min        Animation, Family
# 19  November 12, 2021          2007     PG  110 min  Comedy, Family, Fantasy
#
#                                           description
# 0    Join Mickey and the gang as they duck the halls!
# 19  An animated princess winds up in the real worl...

# %%
ds.drop_duplicates()
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
ds.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
ds["director"].fillna("Chirstoper Nolan")
# Out:
# 0       Alonso Ramirez Ramos, Dave Wasson
# 1                             John Cherry
# 2                            Karen Disher
# 3                         Hamish Hamilton
# 4                        Chirstoper Nolan
#                       ...
# 1445                           Gavin Hood
# 1446                           Shawn Levy
# 1447                      Dexter Fletcher
# 1448                      Gurinder Chadha
# 1449                          Mark Waring
# Name: director, Length: 1450, dtype: object

# %%
ds.dropna()
# Out:
#      show_id   type                                           title  \
# 2         s3  Movie                    Ice Age: A Mammoth Christmas
# 5         s6  Movie                               Becoming Cousteau
# 9        s10  Movie           A Muppets Christmas: Letters To Santa
# 12       s13  Movie                                 The Pixar Story
# 19       s20  Movie                                       Enchanted
# ...      ...    ...                                             ...
# 1445   s1446  Movie                        X-Men Origins: Wolverine
# 1446   s1447  Movie  Night at the Museum: Battle of the Smithsonian
# 1447   s1448  Movie                                 Eddie the Eagle
# 1448   s1449  Movie                            Bend It Like Beckham
# 1449   s1450  Movie           Captain Sparky vs. The Flying Saucers
#
#               director                                               cast  \
# 2         Karen Disher  Raymond Albert Romano, John Leguizamo, Denis L...
# ...

# %%
ds[ds["type"]=="Movie"]
# Out:
#      show_id   type                                             title  \
# 0         s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2  Movie                            Ernest Saves Christmas
# 2         s3  Movie                      Ice Age: A Mammoth Christmas
# 3         s4  Movie                        The Queen Family Singalong
# 5         s6  Movie                                 Becoming Cousteau
# ...      ...    ...                                               ...
# 1445   s1446  Movie                          X-Men Origins: Wolverine
# 1446   s1447  Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448  Movie                                   Eddie the Eagle
# 1448   s1449  Movie                              Bend It Like Beckham
# 1449   s1450  Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# 1                           John Cherry
# ...

# %%
ds[ds["country"]!="United States"]
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# 6         s7  TV Show                                           Hawkeye
# ...      ...      ...                                               ...
# 1444   s1445    Movie                    Ice Age: Dawn Of The Dinosaurs
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
stats.mode(ds["release_year"])
# Out:
# ModeResult(mode=2021, count=125)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1450 non-null   object
#  1   type          1450 non-null   object
#  2   title         1450 non-null   object
#  3   director      977 non-null    object
#  4   cast          1260 non-null   object
#  5   country       1231 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1450 non-null   int64
#  8   rating        1447 non-null   object
#  9   duration      1450 non-null   object
#  10  listed_in     1450 non-null   object
#  11  description   1450 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 136.1+ KB
