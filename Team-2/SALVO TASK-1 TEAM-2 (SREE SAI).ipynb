# %%
import numpy as  np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preprocessing

# %%
df=pd.read_csv("C:/Users/SREE SAI DRONADULA/Desktop/VSCC/Python Programming/jobs_in_data.csv")

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df.tail()
# Out:
#       work_year                 job_title                  job_category  \
# 9350       2021           Data Specialist  Data Management and Strategy
# 9351       2020            Data Scientist     Data Science and Research
# 9352       2021  Principal Data Scientist     Data Science and Research
# 9353       2020            Data Scientist     Data Science and Research
# 9354       2020     Business Data Analyst                 Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 9350             USD  165000         165000      United States
# 9351             USD  412000         412000      United States
# 9352             USD  151000         151000      United States
# 9353             USD  105000         105000      United States
# 9354             USD  100000         100000      United States
#
#      experience_level employment_type work_setting company_location  \
# 9350           Senior       Full-time       Remote    United States
# ...

# %%
print(df.dtypes)
# Out:
# work_year              int64
# job_title             object
# job_category          object
# salary_currency       object
# salary                 int64
# salary_in_usd          int64
# employee_residence    object
# experience_level      object
# employment_type       object
# work_setting          object
# company_location      object
# company_size          object
# dtype: object

# %%
df.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %%
df.describe(include='all')
# Out:
#           work_year      job_title               job_category salary_currency  \
# count   9355.000000           9355                       9355            9355
# unique          NaN            125                         10              11
# top             NaN  Data Engineer  Data Science and Research             USD
# freq            NaN           2195                       3014            8591
# mean    2022.760449            NaN                        NaN             NaN
# std        0.519470            NaN                        NaN             NaN
# min     2020.000000            NaN                        NaN             NaN
# 25%     2023.000000            NaN                        NaN             NaN
# 50%     2023.000000            NaN                        NaN             NaN
# 75%     2023.000000            NaN                        NaN             NaN
# max     2023.000000            NaN                        NaN             NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
df.replace("?",np.nan,inplace=True)

# %%
df
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
df.notnull()
#To check whether null values are present or not
# Out:
#       work_year  job_title  job_category  salary_currency  salary  \
# 0          True       True          True             True    True
# 1          True       True          True             True    True
# 2          True       True          True             True    True
# 3          True       True          True             True    True
# 4          True       True          True             True    True
# ...         ...        ...           ...              ...     ...
# 9350       True       True          True             True    True
# 9351       True       True          True             True    True
# 9352       True       True          True             True    True
# 9353       True       True          True             True    True
# 9354       True       True          True             True    True
#
#       salary_in_usd  employee_residence  experience_level  employment_type  \
# 0              True                True              True             True
# ...

# %%
df.isnull()
#To check whether null values are present or not
# Out:
#       work_year  job_title  job_category  salary_currency  salary  \
# 0         False      False         False            False   False
# 1         False      False         False            False   False
# 2         False      False         False            False   False
# 3         False      False         False            False   False
# 4         False      False         False            False   False
# ...         ...        ...           ...              ...     ...
# 9350      False      False         False            False   False
# 9351      False      False         False            False   False
# 9352      False      False         False            False   False
# 9353      False      False         False            False   False
# 9354      False      False         False            False   False
#
#       salary_in_usd  employee_residence  experience_level  employment_type  \
# 0             False               False             False            False
# ...

# %%
missing_data=df.isnull()

# %%
for column in df:
    print(missing_data[column].value_counts())
    print(" ")
#Finding in each column of the dataset, how many values are missing & In this case, there are no Null values
# Out:
# work_year
# False    9355
# Name: count, dtype: int64
#
# job_title
# False    9355
# Name: count, dtype: int64
#
# job_category
# False    9355
# Name: count, dtype: int64
#
# salary_currency
# False    9355
# Name: count, dtype: int64
#
# salary
# False    9355
# Name: count, dtype: int64
#
# salary_in_usd
# False    9355
# Name: count, dtype: int64
#
# employee_residence
# False    9355
# Name: count, dtype: int64
#
# experience_level
# False    9355
# Name: count, dtype: int64
#
# employment_type
# False    9355
# Name: count, dtype: int64
#
# work_setting
# False    9355
# Name: count, dtype: int64
#
# company_location
# False    9355
# Name: count, dtype: int64
#
# company_size
# False    9355
# Name: count, dtype: int64

# %%
avg_salary=df["salary"].astype("float").mean(axis=0)

# %%
avg_salary
# Out:
# 149927.98129342598

# %%
df['salary_currency'].value_counts()
# Out:
# salary_currency
# USD    8591
# GBP     347
# EUR     340
# CAD      38
# AUD      11
# PLN       7
# SGD       6
# CHF       5
# BRL       4
# TRY       3
# DKK       3
# Name: count, dtype: int64

# %%
df["work_year"].value_counts()
# Out:
# work_year
# 2023    7453
# 2022    1634
# 2021     197
# 2020      71
# Name: count, dtype: int64

# %%
df.dropna(subset="salary",inplace=True,axis=0)
#To remove the row with null values

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
imputer_mean=SimpleImputer(missing_values=np.nan,strategy='mean')
df[['salary']]=imputer_mean.fit_transform(df[['salary']]).astype("object")
#Here we are using sckit-learn to replace the null values by mean if they are present in the dataset
#In Scikit-Learn, inplace=True is not available as in Pandas

# %%
imputer_most_frequent=SimpleImputer(missing_values=np.nan,strategy="most_frequent")
df[["salary_in_usd"]]=imputer_most_frequent.fit_transform(df[["salary_in_usd"]])

# %%
df.dropna(subset="salary",inplace=True,axis=0)
df.reset_index(drop=True,inplace=True)

# %%
missing_data=df.isnull()
for column in df:
    print(missing_data[column].value_counts())
    print(" ")
# Out:
# work_year
# False    9355
# Name: count, dtype: int64
#
# job_title
# False    9355
# Name: count, dtype: int64
#
# job_category
# False    9355
# Name: count, dtype: int64
#
# salary_currency
# False    9355
# Name: count, dtype: int64
#
# salary
# False    9355
# Name: count, dtype: int64
#
# salary_in_usd
# False    9355
# Name: count, dtype: int64
#
# employee_residence
# False    9355
# Name: count, dtype: int64
#
# experience_level
# False    9355
# Name: count, dtype: int64
#
# employment_type
# False    9355
# Name: count, dtype: int64
#
# work_setting
# False    9355
# Name: count, dtype: int64
#
# company_location
# False    9355
# Name: count, dtype: int64
#
# company_size
# False    9355
# Name: count, dtype: int64

# %%
df.to_csv("No_Null_dataset.csv")

# %%
#Data Formatting and Data Binning
tf=['salary','salary_in_usd']

# %%
df[tf]=df[tf].astype("float")

# %%
df.dtypes
# Out:
# work_year               int64
# job_title              object
# job_category           object
# salary_currency        object
# salary                float64
# salary_in_usd         float64
# employee_residence     object
# experience_level       object
# employment_type        object
# work_setting           object
# company_location       object
# company_size           object
# dtype: object

# %%
plt.hist(df['salary_in_usd'])
plt.xlabel("Salary In USD")
plt.ylabel("Frequency Count")
# Out:
# Text(0, 0.5, 'Frequency Count')

# %%
bins=np.linspace(min(df['salary_in_usd']),max(df['salary_in_usd']),4)
bins
# Out:
# array([ 15000., 160000., 305000., 450000.])

# %%
group_names=["Low","Medium","High"]

# %%
df["Salary_Binned"]=pd.cut(df["salary_in_usd"],bins,labels=group_names,include_lowest=True)

# %%
df[["salary_in_usd","Salary_Binned"]].head(10)
# Out:
#    salary_in_usd Salary_Binned
# 0        95012.0           Low
# 1       186000.0        Medium
# 2        81800.0           Low
# 3       212000.0        Medium
# 4        93300.0           Low
# 5       130000.0           Low
# 6       100000.0           Low
# 7       224400.0        Medium
# 8       138700.0           Low
# 9       210000.0        Medium

# %%
df["Salary_Binned"].value_counts()
# Out:
# Salary_Binned
# Low       5750
# Medium    3432
# High       173
# Name: count, dtype: int64

# %%
df['job_title'].unique()
df["job_category"].unique()
# Out:
# array(['Data Engineering', 'Data Architecture and Modeling',
#        'Data Science and Research', 'Machine Learning and AI',
#        'Data Analysis', 'Leadership and Management',
#        'BI and Visualization', 'Data Quality and Operations',
#        'Data Management and Strategy', 'Cloud and Database'], dtype=object)

# %%
plt.bar(group_names,df["Salary_Binned"].value_counts(),color='b')
plt.xlabel("Salary in USD",color='g')
plt.ylabel("Count",color='orange')
# Out:
# Text(0, 0.5, 'Count')

# %%
# One-Hot Encoding and Label Encoding
job_category_dummy=pd.get_dummies(df["job_category"])
job_category_dummy
# Out:
#       BI and Visualization  Cloud and Database  Data Analysis  \
# 0                    False               False          False
# 1                    False               False          False
# 2                    False               False          False
# 3                    False               False          False
# 4                    False               False          False
# ...                    ...                 ...            ...
# 9350                 False               False          False
# 9351                 False               False          False
# 9352                 False               False          False
# 9353                 False               False          False
# 9354                 False               False           True
#
#       Data Architecture and Modeling  Data Engineering  \
# 0                              False              True
# 1                               True             False
# ...

# %%
# df=pd.concat([df,job_category_dummy])
# df["company_location"].value_counts()

# %%
df.drop("salary",axis=1,inplace=True)
df.drop("salary_currency",axis=1,inplace=True)
df.head(10)
# Out:
#    work_year                    job_title                    job_category  \
# 0       2023         Data DevOps Engineer                Data Engineering
# 1       2023               Data Architect  Data Architecture and Modeling
# 2       2023               Data Architect  Data Architecture and Modeling
# 3       2023               Data Scientist       Data Science and Research
# 4       2023               Data Scientist       Data Science and Research
# 5       2023               Data Scientist       Data Science and Research
# 6       2023               Data Scientist       Data Science and Research
# 7       2023  Machine Learning Researcher         Machine Learning and AI
# 8       2023  Machine Learning Researcher         Machine Learning and AI
# 9       2023                Data Engineer                Data Engineering
#
#    salary_in_usd employee_residence experience_level employment_type  \
# 0        95012.0            Germany        Mid-level       Full-time
# ...

# %%
df["job_category"].value_counts()
# Out:
# job_category
# Data Science and Research         3014
# Data Engineering                  2260
# Data Analysis                     1457
# Machine Learning and AI           1428
# Leadership and Management          503
# BI and Visualization               313
# Data Architecture and Modeling     259
# Data Management and Strategy        61
# Data Quality and Operations         55
# Cloud and Database                   5
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder as le

# %%
df["company_size"].value_counts()
# df["experience_level"].value_counts
# Out:
# company_size
# M    8448
# L     748
# S     159
# Name: count, dtype: int64

# %%
# df["company_size"]=le.fit_transform(df['company_size'])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[8])],remainder="passthrough")
# df=pd.DataFrame(ct.fit_transform(df))

# %%
#Train and Test Splitting of DataSet
df1=pd.read_excel("C:/Users/SREE SAI DRONADULA/Desktop/VSCC/Python Programming/Salary_Dataset_02.xls")

# %%
df1.head()
# Out:
#    Australia  Canada  Dubai  USA  Salary  YearsExperience  Purchased
# 0          0       0      1    0   39343              1.1          0
# 1          0       1      0    0   46205              1.3          1
# 2          0       1      0    0   37731              1.5          0
# 3          0       1      0    0   43525              2.0          0
# 4          0       0      0    1   39891              2.2          0

# %%
X=df1.iloc[:,0:6]
y=df1.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split as tts

# %%
X_train,X_test,y_train,y_test=tts(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience
# 26          0       0      1    0  116969              9.5
# 3           0       1      0    0   43525              2.0
# 24          0       0      1    0  109431              8.7
# 22          1       0      0    0  101302              7.9
# 23          1       0      0    0  113812              8.2
# 4           0       0      0    1   39891              2.2
# 2           0       1      0    0   37731              1.5
# 25          1       0      0    0  105582              9.0
# 6           0       1      0    0   60150              3.0
# 18          1       0      0    0   81363              5.9
# 13          0       1      0    0   57081              4.1
# 7           1       0      0    0   54445              3.2
# 27          0       0      0    1  112635              9.6
# 1           0       1      0    0   46205              1.3
# 16          0       0      0    1   66029              5.1
# ...

# %%
#Importing StandardScaler
from sklearn.preprocessing import StandardScaler
#Creating Instance of StandarScaler
sc = StandardScaler()
#Perform scaling in X_train with fit_transform.
#Here we are applying fit_transform because,
        # fit will calculate mean and standard deviation of X_train
        # transform will actually perform scaling with calculated mean and std.
        # fit_transform method does this both thing in one line of code.
X_train.iloc[:, 4:] = sc.fit_transform(X_train.iloc[:, 4:])

# Here we will only use transform because we have already calculated mean and std.
# Another reason is we don't want to know the mean and std of our test dataset As it
# Lead to information leakage.
X_test.iloc[:, 4:] = sc.transform(X_test.iloc[:, 4:])

# %%
X_train
# Out:
#     Australia  Canada  Dubai  USA    Salary  YearsExperience
# 26          0       0      1    0  1.461305         1.391080
# 3           0       1      0    0 -1.067603        -1.058963
# 24          0       0      1    0  1.201748         1.129742
# 22          1       0      0    0  0.921841         0.868404
# 23          1       0      0    0  1.352600         0.966406
# 4           0       0      0    1 -1.192733        -0.993629
# 2           0       1      0    0 -1.267108        -1.222299
# 25          1       0      0    0  1.069215         1.227744
# 6           0       1      0    0 -0.495152        -0.732291
# 18          1       0      0    0  0.235279         0.215059
# 13          0       1      0    0 -0.600827        -0.372951
# 7           1       0      0    0 -0.691593        -0.666956
# 27          0       0      0    1  1.312072         1.423747
# 1           0       1      0    0 -0.975322        -1.287634
# ...

# %%
X_test
# Out:
#     Australia  Canada  Dubai  USA    Salary  YearsExperience
# 17          0       1      0    0  0.294676         0.019056
# 21          1       0      0    0  0.817543         0.607066
# 10          0       0      1    0 -0.389511        -0.438286
# 19          0       1      0    0  0.668344         0.247727
# 14          1       0      0    0 -0.462061        -0.242282
# 20          0       1      0    0  0.592523         0.509065

# %% [markdown]
# # Data Cleaning

# %%
df2=pd.read_excel("C:/Users/SREE SAI DRONADULA/Desktop/VSCC/Python Programming/Customer Call List.xlsx")

# %%
df2
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df2=df2.drop_duplicates()
df2
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df2=df2.drop(columns="Not_Useful_Column")
df2
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df2["Last_Name"]=df2["Last_Name"].str.strip("123._/")
df2
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
# df2["Phone_Number"]=df2["Phone_Number"].str.replace('[^\\d]+','')
# df2["Phone_Number"]=df2["Phone_Number"].str.replace('[^a-zA-Z0-9]+','')
# df2["Phone_Number"]=df2["Phone_Number"].apply(lambda x:str(x))
# df2["Phone_Number"].apply(lambda x:x[0:3]+"-"+x[3:6]+"-"+x[6:10])
# df2['Phone_Number'].str.replace('[/|-]+', '')
df2["Phone_Number"]=df2['Phone_Number'].str.replace('-', '')
df2["Phone_Number"]=df2['Phone_Number'].str.replace('/', '')
df2["Phone_Number"]=df2['Phone_Number'].str.replace('|', '')

# %%
df2["Phone_Number"]=df2["Phone_Number"].apply(lambda x:str(x))
df2["Phone_Number"]=df2["Phone_Number"].apply(lambda x:x[0:3]+"-"+x[3:6]+"-"+x[6:10])
df2["Phone_Number"]=df2["Phone_Number"].str.replace("nan--","")
df2["Phone_Number"]=df2["Phone_Number"].str.replace("Na--","")
df2
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
# df2[["Street_Address","State","Zip_Code"]]=df2["Address"].str.split(',',2,expand=True)

# %%
df2["Paying Customer"]=df2["Paying Customer"].str.replace("Yes","Y")
df2["Paying Customer"]=df2["Paying Customer"].str.replace("No","N")
df2["Do_Not_Contact"]=df2["Paying Customer"].str.replace("Yes","Y")
df2["Do_Not_Contact"]=df2["Paying Customer"].str.replace("No","N")

# %%
df2["Paying Customer"]=df2["Paying Customer"].str.replace("N/a","")
df2["Do_Not_Contact"]=df2["Do_Not_Contact"].str.replace("N/a","")
df2["Address"]=df2["Address"].str.replace("N/a","")

# %%
df2
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
for x in df2.index:
    if df2.loc[x,"Do_Not_Contact"]=="Y":
        df2.drop(x,inplace=True)

# %%
for x in df2.index:
    if df2.loc[x,"Phone_Number"]=="":
        df2.drop(x,inplace=True)

# %%
df2=df2.reset_index(drop=True)
df2
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0        1002       Abed       Nadir  123-643-9775   93 West Main Street
# 1        1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 2        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 3        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
#
#   Paying Customer Do_Not_Contact
# 0               N              N
# 1               N              N
# 2               N              N
# 3               N              N

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#       salary_in_usd employee_residence experience_level employment_type  \
# ...

# %% [markdown]
# # Data Visualization

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]
plt.plot(yield_apples)

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]
plt.plot(years,yield_apples)
plt.xlabel("Years")
plt.ylabel("Yield(tons per hectare)")
plt.title("Apple's Yield")
# Out:
# Text(0.5, 1.0, "Apple's Yield")

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]
plt.plot(years,apples,marker='o')
plt.plot(years,oranges,marker='x')
plt.xlabel("Year")
plt.ylabel("Yield(tons per hectare)")
plt.title("Crops In TJ")
plt.legend(["Apples","Oranges"])
plt.show()

# %%
# plt.plot(years,apples,"o-b")
# plt.plot(years,oranges,"s--r")
plt.plot(years,apples,marker="o",ls="-",lw="2",ms="8",mew="2",mec="navy",mfc="g",alpha=.5)
plt.plot(years,oranges,marker="s",ls="--",lw="2",ms="8",mew="2",mec="orange",mfc="y",alpha=.5)
# plt.plot(years,apples,"ob")
# plt.plot(years,oranges,"sr")
plt.xlabel("year")
plt.legend(["Apples","Oranges"])
plt.title("Crops in TJ")
plt.ylabel("Yield(tons per hectare)")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(years,oranges,"or")
plt.title("Crops(tons per hectare)")
plt.show()

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o--r')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
# pip install pandoc

# %%
sns.set_style("darkgrid")
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o--r')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years, oranges, 'or')
plt.title("Yield of Oranges (tons per hectare)");

# %%
import matplotlib
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
flowers_df=sns.load_dataset("iris")

# %%
flowers_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df.sepal_length,flowers_df.sepal_width);

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width,hue=flowers_df.species,s=100)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(12,6))
plt.title("Sepal Dimensions")
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width,hue=flowers_df.species,s=78)
# Out:
# <Axes: title={'center': 'Sepal Dimensions'}, xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.title("Sepal Dimensions")
sns.scatterplot(x="sepal_length",
               y="sepal_width",
               hue="species",
                s=100,
               data=flowers_df)
# Out:
# <Axes: title={'center': 'Sepal Dimensions'}, xlabel='sepal_length', ylabel='sepal_width'>

# %%
#Histogram
flowers_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title("Distribution of Sepal width")
plt.hist(flowers_df.sepal_width,bins=5)
# Out:
# (array([11., 46., 68., 21.,  4.]),
#  array([2.  , 2.48, 2.96, 3.44, 3.92, 4.4 ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(flowers_df.sepal_width,bins=np.arange(2,5,0.25))
# Out:
# (array([ 4.,  7., 22., 24., 50., 18., 13.,  8.,  3.,  1.,  0.]),
#  array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#         4.75]),
#  <BarContainer object of 11 artists>)

# %%
plt.hist(flowers_df.sepal_width,bins=[1,3,4,4.5])
# Out:
# (array([57., 89.,  4.]),
#  array([1. , 3. , 4. , 4.5]),
#  <BarContainer object of 3 artists>)

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
plt.hist(setosa_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25))
plt.hist(versicolor_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25))
# Out:
# (array([ 3.,  6., 12., 13., 14.,  2.,  0.,  0.,  0.,  0.,  0.]),
#  array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#         4.75]),
#  <BarContainer object of 11 artists>)

# %%
plt.title("Distribution of Sepal Width")
plt.hist([setosa_df.sepal_width,versicolor_df.sepal_width,virginica_df.sepal_width],bins=np.arange(2,5,0.25),stacked=True)
plt.legend(["Setosa","Versicolor","Virginica"])

# %%
#Bar Chart
years=range(2000,2006)
apples=[0.35,0.6,0.9,0.8,0.65,0.8]
oranges=[0.4,0.8,0.9,0.7,0.6,0.8]

# %%
plt.bar(years,oranges)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(years,apples)
plt.bar(years,oranges,bottom=apples);

# %%
tips_df=sns.load_dataset("tips")

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x="day",y="total_bill",data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="day",y="total_bill",hue="sex",data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="total_bill",y="day",hue="sex",data=tips_df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
# #Heat Map
# flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")

# %%
# flights_df

# %%
# plt.title("No of passengers (1000s)")
# sns.heatmap(flights_df)

# %%
# plt.title("No of Passengers (1000s)")
# sns.heatmap(flights_df,fmt="d",cmap="b",annot=True)

# %%
#Images
from urllib.request import urlretrieve

# %%
urlretrieve('https://i.imgur.com/SkPbq.jpg', 'chart.jpg')
# Out:
# ('chart.jpg', <http.client.HTTPMessage at 0x25a595d3e10>)

# %%
from PIL import Image

# %%
img=Image.open("chart.jpg")

# %%
img_arr=np.array(img)

# %%
img_arr.shape
# Out:
# (481, 640, 3)

# %%
plt.imshow(img)

# %%
plt.grid(False)
plt.axis("off")
plt.imshow(img)

# %%
plt.grid(False)
plt.axis("off")
plt.imshow(img_arr[125:300,100:299])

# %%
#Pair plots with seaborn
sns.pairplot(flowers_df,hue="species")
# Out:
# C:\Users\SREE SAI DRONADULA\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Plotting multiple charts in a grid

# %% [markdown]
# # Data Analysis

# %%
#Calculate Mean,Median,Mode and Standard deviation
mean_salary=df["salary_in_usd"].mean()
mode_salary=df["salary_in_usd"].mode()
median_salary=df["salary_in_usd"].median()
std_salary=df["salary_in_usd"].std()

# %%
print(f"Mean Salary: {mean_salary:.2f}")
print(f"Median Salary: {median_salary:.2f}")
print(f"Mode Salary: {mode_salary:}")
print(f"Standard Deviation: {std_salary:.2f}")
# Out:
# Mean Salary: 146258.41
# Median Salary: 140000.00
# Mode Salary: 0    100000.0
# Name: salary_in_usd, dtype: float64
# Standard Deviation: 66594.12

# %%
#let us try plotting the measures on a graph
import matplotlib.pyplot as plt
import seaborn as sns

# Plot histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['salary_in_usd'], bins=30, kde=True, color='skyblue')

# Plot vertical lines for mean, median, and mode
plt.axvline(df['salary_in_usd'].mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(df['salary_in_usd'].median(), color='green', linestyle='dashed', linewidth=2, label='Median')
plt.axvline(df['salary_in_usd'].mode().iloc[0], color='orange', linestyle='dashed', linewidth=2, label='Mode')

# Add labels and title
plt.title('Distribution of Salary in USD with Mean, Median, and Mode')
plt.xlabel('Salary in USD')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %%
#lets just try plotting the normal salary, since differnt currencies were used, we would expect to see clusters

#let us try plotting the measures on a graph
import matplotlib.pyplot as plt
import seaborn as sns

# Plot histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['salary_in_usd'], bins=30, kde=True, color='red')

# Plot vertical lines for mean, median, and mode
plt.axvline(df['salary_in_usd'].mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(df['salary_in_usd'].median(), color='green', linestyle='dashed', linewidth=2, label='Median')
plt.axvline(df['salary_in_usd'].mode().iloc[0], color='orange', linestyle='dashed', linewidth=2, label='Mode')

# Add labels and title
plt.title('Distribution of Salary with Mean, Median, and Mode')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %%
#Our distribution seems very similar to the usd one, so lets see the ratio of all currencies
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame 'df' with a column 'employee_residence'
# If not, replace it with the actual column name in your DataFrame

# Plot bar plot for count of entries for each country
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='employee_residence', order=df['employee_residence'].value_counts().index, palette='viridis')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=90)

# Add labels and title
plt.title('Count of Entries for Each Country')
plt.xlabel('Country')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Identify the top 12 countries based on entry count
top_countries = df['employee_residence'].value_counts().nlargest(12).index

# Create separate plots for each of the top 12 countries with mean, median, mode, and standard deviation
plt.figure(figsize=(15, 15))

for i, country in enumerate(top_countries, 1):
    plt.subplot(4, 3, i)
    country_data = df[df['employee_residence'] == country]['salary_in_usd']
    sns.histplot(country_data, bins=30, kde=True, color='skyblue')
    plt.axvline(country_data.mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
    plt.axvline(country_data.median(), color='green', linestyle='dashed', linewidth=2, label='Median')
    plt.axvline(country_data.mode().iloc[0], color='orange', linestyle='dashed', linewidth=2, label='Mode')
    plt.title(f'Salary Distribution in {country}\nStd Dev: {country_data.std():.2f}')
    plt.xlabel('Salary')
    plt.ylabel('Frequency')
    plt.legend()

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
# #trying heatmaps

# import matplotlib.pyplot as plt
# import seaborn as sns

# # Create a heatmap for the entire correlation matrix
# plt.figure(figsize=(12, 10))
# heatmap_data = df.corr()
# heatmap = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt=".2f")

# # Add labels and title
# plt.title('Heatmap - Correlation Matrix of All Columns')
# plt.show()

# """
# ): Not significant related data for heatmaps
# """

# ""
